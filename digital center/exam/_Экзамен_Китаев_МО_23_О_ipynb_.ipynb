# %% [markdown]
# **Экзамен по курсу "Машинное обучение"**

# %% [markdown]
# Выполнил: *Китаев Степан Максимович, группа МО-23-О*
#
# Филиал: *НИЯУ МИФИ (московствкая площадка)*

# %% [markdown]
#  *Вставьте ниже скриншот из личного кабинета Иннополиса с результатами прохождения итогового асессмента (https://auth.unionepro.ru/login?redirect=https%3A%2F%2Fassessment.unionepro.ru%2F)*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# # 1. Исходные данные

# %% [markdown]
# ### 1.1 Загрузка библиотек и данных

# %% [markdown]
# *Загрузить данные в соответствии с вариантом задания*

# %%
# Load data

from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()

# %%
# Import libraries
import pandas as pd
import numpy as np

data_df = pd.DataFrame(data = data.data, columns = data.feature_names)

data_df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
data.target_names
# Out:
# array(['malignant', 'benign'], dtype='<U9')

# %%
data.feature_names
# Out:
# array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error',
#        'fractal dimension error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst smoothness',
#        'worst compactness', 'worst concavity', 'worst concave points',
#        'worst symmetry', 'worst fractal dimension'], dtype='<U23')

# %% [markdown]
# ### 1.2 Описание исходных данных

# %% [markdown]
# *Привести описание исходных данных, описание и типы признаков (вещественные, целочисленные, категориальные и т.д.), объём выборки, особенности данных. Сформулировать решаемую задачу, определить тип задачи (регрессия / классификация), указать входные и выходные переменные.*

# %% [markdown]
# Исходныйе данные это датасет (таблица) столбцы - 30 параметров исследования рака груди, и 569ю записями. Для всех столбцов значения приведены в действительных числах. Это задача классификации, данные необходимо классифицировать в 2 класса по виду обнаруженной опухоли (злокачественная/доброкачественная)
#
#
# Входные данные - атрибуты
#
#
# 'mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error',
#        'fractal dimension error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst smoothness',
#        'worst compactness', 'worst concavity', 'worst concave points',
#        'worst symmetry', 'worst fractal dimension'
#
#
# Выходные данные - 2 класса
#
#
# 'malignant', 'benign'

# %% [markdown]
# ### 1.3 Выборочные характеристики

# %% [markdown]
# *Рассчитать основные выборочные характеристики (среднее, дисперсию, среднеквадратическое отклонение, медиану и т.д.), привести объемы выборок в каждом классе (для задач классификации)*

# %%
# TODO
df_variables = pd.concat([data_df.mean(), data_df.median(), data_df.std()**2, data_df.std(), data_df.max() - data_df.min()], axis = 1)
df_variables = df_variables.rename(columns={0: 'mean', 1: 'median', 2: 'var', 3: 'std', 4: 'range'})

malignant = 0
for i in range(len(data.target)):
  if data.target[i] == 0:
    malignant += 1

benign = len(data.target) - malignant

volume = {'malignant': malignant, 'benign': benign}

print("Основные выбороные характеристики по каждому атрибуту:")
print(df_variables)
print()
print("Объем выборок:")
print(volume)
# Out:
# Основные выбороные характеристики по каждому атрибуту:
#                                mean      median            var         std  \
# mean radius               14.127292   13.370000      12.418920    3.524049
# mean texture              19.289649   18.840000      18.498909    4.301036
# mean perimeter            91.969033   86.240000     590.440480   24.298981
# mean area                654.889104  551.100000  123843.554318  351.914129
# mean smoothness            0.096360    0.095870       0.000198    0.014064
# mean compactness           0.104341    0.092630       0.002789    0.052813
# mean concavity             0.088799    0.061540       0.006355    0.079720
# mean concave points        0.048919    0.033500       0.001506    0.038803
# mean symmetry              0.181162    0.179200       0.000752    0.027414
# mean fractal dimension     0.062798    0.061540       0.000050    0.007060
# radius error               0.405172    0.324200       0.076902    0.277313
# ...

# %% [markdown]
# ### 1.4 Исследование распределений признаков и откликов

# %% [markdown]
# *Построить гистограммы распределения и диаграммы Box-and-Whisker (для отдельных признаков при большом их числе), сделать выводы о характере распределений признаков (для задач классификации - в классах), наличии выбросов и т.п.*

# %%
# TODO
mal_l = []
ben_l = []

# Разделил данные по классам
for i in range(len(data.data)):
  if data.target[i] == 0:
    mal_l.append(data.data[i])
  else:
    ben_l.append(data.data[i])

col_names1 = []
col_names2 = []

for i in range(len(data.feature_names)):
  b = 'malignant ' +  data.feature_names[i]
  col_names1.append(b)

for i in range(len(data.feature_names)):
  b = 'benign ' +  data.feature_names[i]
  col_names2.append(b)

malignant_df = pd.DataFrame(data = mal_l, columns = col_names1)
benign_df = pd.DataFrame(data = ben_l, columns = col_names2)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# гистограммы распределения
plt.figure(figsize=(12, 30))  # Размер графика
plt.subplot(6, 2, 1)
sns.histplot([malignant_df['malignant mean radius'], benign_df['benign mean radius']], bins = 30, legend = True)
plt.title('Распределение среднего радиуса опухоли')

plt.subplot(6, 2, 2)
sns.histplot([malignant_df['malignant mean texture'], benign_df['benign mean texture']], bins = 30, legend = True)
plt.title('Распределение показателя текстуры опухоли')

plt.subplot(6, 2, 3)
sns.histplot([malignant_df['malignant mean perimeter'], benign_df['benign mean perimeter']], bins = 30, legend = True)
plt.title('Распределение среднего периметра опухоли')

plt.subplot(6, 2, 4)
sns.histplot([malignant_df['malignant mean area'], benign_df['benign mean area']], bins = 30, legend = True)
plt.title('Распределение средней площади опухоли')

plt.subplot(6, 2, 5)
sns.histplot([malignant_df['malignant mean smoothness'], benign_df['benign mean smoothness']], bins = 30, legend = True)
plt.title('Распределение гладкости опухоли')

plt.subplot(6, 2, 6)
sns.histplot([malignant_df['malignant mean symmetry'], benign_df['benign mean symmetry']], bins = 30, legend = True)
plt.title('Распределение показателя симметрии опухоли')

#графики box-and-whisker
plt.subplot(6, 2, 7)
sns.boxplot([malignant_df['malignant mean radius'], benign_df['benign mean radius']])
plt.title('Диаграмма среднего радиуса опухоли по классу')

plt.subplot(6, 2, 8)
sns.boxplot([malignant_df['malignant mean texture'], benign_df['benign mean texture']])
plt.title('Диаграмма показателя текстуры опухоли по классу')

plt.subplot(6, 2, 9)
sns.boxplot([malignant_df['malignant mean perimeter'], benign_df['benign mean perimeter']])
plt.title('Диаграмма среднего периметра опухоли по классу')

plt.subplot(6, 2, 10)
sns.boxplot([malignant_df['malignant mean area'], benign_df['benign mean area']])
plt.title('Диаграмма средней площади опухоли по классу')

plt.subplot(6, 2, 11)
sns.boxplot([malignant_df['malignant mean smoothness'], benign_df['benign mean smoothness']])
plt.title('Диаграмма гладкости опухоли по классу')

plt.subplot(6, 2, 12)
sns.boxplot([malignant_df['malignant mean symmetry'], benign_df['benign mean symmetry']])
plt.title('Диаграмма симметрии опухоли по классу')

plt.show()

# %% [markdown]
# Гистограммы показывают, что доброкачественные опухоли имеют в основном нормальное распределение, в то время как рапределение признаков у злокачественных опухолей не нормализовано. Параметры злокачетсвенных опухолей имеют в среднем большие количественные оценки по ряду параметров: средний радиус, текстура, гладкость, симметрия, периметр и площадь. Графики box-and-whisker подтверждают что в среднем все количественные характеристики у данных по злокачественных опухолям выше, чем по доброкачественным. Распределение признаков доброкачественных опухолей симметрично, чего нельзя сказать о распределении признаков злокачественных опухолей. Присутствуют выбросы как в данных доброкачественных так и злокачественных опухолей.

# %% [markdown]
# ### 1.5 Корреляционный анализ данных

# %% [markdown]
# *Визуализировать диаграммы рассеяния и корреляционную матрицу признаков, сделать выводы*

# %%
# TODO

#Диаграммы рассеяния
sns.scatterplot(data=data_df, x='mean symmetry', y='mean area')
plt.title('Диаграмма рассеяния между Признаком mean symmetry и Признаком mean area')
plt.show()

sns.scatterplot(data=data_df, x='mean radius', y='mean area')
plt.title('Диаграмма рассеяния между Признаком mean radius и Признаком mean area')
plt.show()

sns.scatterplot(data=data_df, x='mean perimeter', y='mean area')
plt.title('Диаграмма рассеяния между Признаком mean perimeter и Признаком mean area')
plt.show()

sns.scatterplot(data=data_df, x='mean smoothness', y='mean texture')
plt.title('Диаграмма рассеяния между Признаком mean smoothness и Признаком mean texture')
plt.show()

sns.scatterplot(data=data_df, x='mean symmetry', y='mean texture')
plt.title('Диаграмма рассеяния между Признаком mean symmetry и Признаком mean texture')
plt.show()

# %%
#Корреляционная матрица
plt.figure(figsize=(25, 25))
sns.heatmap(data_df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Корреляционная матрица признаков')
plt.show()

# %% [markdown]
# Из визуальной оценки можно понять, что размерные признаки (радиус площадь и периметр) опухоли сильно коррелируют друг с другом. признак mean concavity сильно коррелирует с большинством признаков. Параметры текстуры слабо коррелирует со всеми остальными признаками как и параметр гладкости. Параметр симметрии средне коррелирует с вогнутостью опухоли как и "fractal dimention"

# %% [markdown]
# ### 1.6 Выводы

# %% [markdown]
# *Сделать выводы по результатам предварительного визуального анализа исходных данных*

# %% [markdown]
# 1) Датасет состоит из 569 записей по 30 признакам, данным по опухоли груди (молочной железы).
#
#
# 2) Поставлена задача бинарной классификации - распределение данных по 2м классам - (malignant и benign), то есть классифицировать данные, чтобы определить является ли найденная опухоль доброкачественной или злокачественной.
#
#
# 3) Распределение признаков для записей, классифицированных как доброкачественные выглядит нормальным, чего нельзя сказать о записях, которые классифицируются как злокачественные.
#
#
# 4) Средние значения признаков для злокачетсвенных опухолей в среднем выше, чем средние величины доброкачественных опухолей. Данные для доброкачественнных опухолей имеют меньшее среднеквадратическое отклонение и симметричны, в отличие от данных для злокачественных опухолей
#
#
# 5) Незначительные выбросы присутствуют во всех признаках в обоих классах
#
#
# 6) Корреляционная матрица показывает, что все размерные признаки опухолей сильно коррелируют друг с другом. Вогнутость опухоли коррелирует средне с многими признаками.

# %% [markdown]
# ---
# # 2. Предобработка данных

# %% [markdown]
# ### 2.1 Очистка данных

# %% [markdown]
# *а) Обнаружение и устранение дубликатов*\
# *б) Обнаружение и устранение выбросов*\
# *в) Устранение/восстановление пропущенных значений*

# %%
# TODO

# Вывод количества пропученных значений
missing_values = data_df.isnull().sum()

print(missing_values) # Пропущенных значений нет

# Подсчет количества дубликатов

dublicate = 0

dub_data = []

for i in range(len(data.data)):
  for j in range(i+1,len(data.data)):
    if np.array_equal(data.data[i], data.data[j]) == True:
      dublicate += 1

print("Количество дубликатов: ", dublicate) # Дубликатов нет

# Обнаружение и устранение выбросов

# Данные с выбросами обнаружены в разделе 1.4, далее будет очистка данных со знаениями превосходящими среднекватратическое отклонение на графиках box-and-whisker

# Устранение выбросов в данных по злокачественным опухолям
c_malignant_df = malignant_df

for i in range(len(c_malignant_df)):
  if c_malignant_df['malignant mean radius'][i] > 26 or c_malignant_df['malignant mean perimeter'][i] > 175 or c_malignant_df['malignant mean smoothness'][i] > 0.14 or c_malignant_df['malignant mean texture'][i] < 14 or c_malignant_df['malignant mean texture'][i] > 30 or c_malignant_df['malignant mean area'][i] > 2000 or c_malignant_df['malignant mean symmetry'][i] > 0.265:
    c_malignant_df.drop(labels = [i], axis = 0, inplace = True)

# Устранение выбросов в данных по доброкачественным опухолям

c_benign_df = benign_df

for i in range(len(c_benign_df)):
  if c_benign_df['benign mean radius'][i] > 17 or c_benign_df['benign mean perimeter'][i] > 110 or c_benign_df['benign mean perimeter'][i] < 50 or c_benign_df['benign mean smoothness'][i] > 0.13 or c_benign_df['benign mean texture'][i] > 25 or c_benign_df['benign mean area'][i] > 800 or c_benign_df['benign mean symmetry'][i] > 0.24:
    c_benign_df.drop(labels = [i], axis = 0, inplace = True)
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# dtype: int64
# Количество дубликатов:  0
# ...

# %% [markdown]
# ### 2.2 Разбиение данных на обучающую и тестовую выборки

# %% [markdown]
# *Разбить данные на обучающую и тестовую выборки в отношении 70/30*

# %%
# TODO

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.3)

# %% [markdown]
# ### 2.3 Преобразование данных

# %% [markdown]
# *Описать используемые способы преобразования входных и выходных переменных, привести обоснования выбранных способов преобразования, применить преобразования к обучающей и тестовой выборкам*

# %% [markdown]
# TODO
# Так как задача бинарной классификации в общем случае является простой, то я решил использовать модель логистической регрессии для ее решения. Так как в изначальных данных нет категориальных значений и пропусков, то метод подходит и вся предобработка выполнена

# %% [markdown]
# ---
# # 3. Построение и исследование модели машинного обучения

# %% [markdown]
# ### 3.1 Обучение модели

# %% [markdown]
# *Выбрать модель и алгоритм машинного обучения для решения поставленной задачи, привести обоснование выбора, обучить модель на обучающей выборке*

# %%
# TODO

from sklearn.linear_model import LogisticRegression
from sklearn import metrics

logreg = LogisticRegression()
logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)
print('Точность логистистической регрессии: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Точность логистистической регрессии: 0.95
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### 3.2 Оценка качества модели

# %% [markdown]
# **Для задач регрессии:**
# * *построить диаграммы рассеяния в пространстве «выход модели – желаемый выход» на данных обучающей и тестовой выборок*
# * *построить линейные регрессии выхода модели на желаемый выход*
# * *рассчитать коэффициенты детерминации линейных регрессионных моделей для обучающей и тестовой выборок*
# * *построить гистограммы распределения ошибок модели.*
#
# **Для задач классификации:**
# * *построить матрицы ошибок (confusion matrix) классификатора и рассчитать показатели качества классификации (чувствительность, специфичность, точность, F-мера, каппа Коэна) на обучающей и тестовой выборках.*

# %%
# TODO

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, cohen_kappa_score

# Визуализация матрицы ошибок
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[0, 1], yticklabels=[0, 1])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Матрица ошибок')
plt.show()

# Расчет показателей качества классификации

# Предсказания на обучающей выборке
y_train_pred = logreg.predict(X_train)

# Предсказания на тестовой выборке
y_test_pred = logreg.predict(X_test)

# Функция для расчета метрик
def print_classification_metrics(y_true, y_pred, dataset_name):
    # Матрица ошибок
    cm = confusion_matrix(y_true, y_pred)
    TN, FP, FN, TP = cm.ravel()

    # Метрики
    accuracy = accuracy_score(y_true, y_pred)
    sensitivity = recall_score(y_true, y_pred)  # TPR: Чувствительность (или полнота)
    specificity = TN / (TN + FP)                # TNR: Специфичность
    precision = precision_score(y_true, y_pred) # Точность
    f1 = f1_score(y_true, y_pred)               # F1-мера
    kappa = cohen_kappa_score(y_true, y_pred)   # Каппа Коэна

    # Вывод метрик
    print()
    print(f"--- Метрики для {dataset_name} выборки ---")
    print(f"Точность: {accuracy:.4f}")
    print(f"Чувствительность: {sensitivity:.4f}")
    print(f"Специфичность: {specificity:.4f}")
    print(f"Точность: {precision:.4f}")
    print(f"F-мера: {f1:.4f}")
    print(f"Каппа Коэна: {kappa:.4f}")
    print()

# Расчет метрик для обучающей выборки
print_classification_metrics(y_train, y_train_pred, "обучающей")

# Расчет метрик для тестовой выборки
print_classification_metrics(y_test, y_test_pred, "тестовой")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-6063f7e85915> in <cell line: 8>()
#       6
#       7 # Визуализация матрицы ошибок
# ----> 8 plt.figure(figsize=(6, 4))
#       9 sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[0, 1], yticklabels=[0, 1])
#      10 plt.xlabel('Predicted')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### 3.3 Исследование модели и алгоритма обучения

# %% [markdown]
# *Провести экспериментальные исследования модели, построить графики зависимости ошибки модели от ее архитектурных параметров и гиперпараметров алгоритма обучения, построить ROC-кривые, оценить степень важности признаков и пр.*

# %%
# Определяю гиперпараметры модели и нахожу лучшую модель
from sklearn.model_selection import GridSearchCV

param_grid = {
    'C': [0.01, 0.1, 1, 10, 15, 50, 100],     # Коэффициент регуляризации
    'penalty': ['l1', 'l2']           # Тип регуляризации (L1 и L2)
}

# поиск оптимальных гиперпараметров
grid_search = GridSearchCV(estimator=logreg, param_grid=param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Лучшая модель по результатам поиска
best_clf = grid_search.best_estimator_

print("Лучшие гиперпараметры:", grid_search.best_params_)
print("Лучшая точность на обучающей выборке:", grid_search.best_score_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# Лучшие гиперпараметры: {'C': 15, 'penalty': 'l2'}
# Лучшая точность на обучающей выборке: 0.9421518987341772

# %%
coefficients = best_clf.coef_[0]

# важность признаков
feature_importance_df = pd.DataFrame({
    'Feature': data.feature_names,
    'Coefficient': coefficients
}).sort_values(by='Coefficient', ascending=False)

print(feature_importance_df)

# график важности признаков
plt.figure(figsize=(8, 6))
sns.barplot(x='Coefficient', y='Feature', data=feature_importance_df)
plt.title('Важность признаков')
plt.show()
# Out:
#                     Feature  Coefficient
# 0               mean radius     2.449367
# 20             worst radius     2.405770
# 11            texture error     1.476692
# 12          perimeter error     0.504362
# 1              mean texture     0.188425
# 10             radius error     0.098204
# 3                 mean area     0.004335
# 19  fractal dimension error    -0.008763
# 14         smoothness error    -0.009036
# 9    mean fractal dimension    -0.027474
# 23               worst area    -0.028245
# 18           symmetry error    -0.034610
# 17     concave points error    -0.037966
# 15        compactness error    -0.083505
# 4           mean smoothness    -0.107745
# 16          concavity error    -0.134884
# 29  worst fractal dimension    -0.147478
# 13               area error    -0.150724
# 8             mean symmetry    -0.177225
# 24         worst smoothness    -0.193283
# 2            mean perimeter    -0.206444
# 22          worst perimeter    -0.220815
# ...

# %% [markdown]
# Выдление важности признаков показало, что самыми важными признаками являются средний радиус, периметр и текстурные параметры

# %%
# TODO

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC кривая')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %% [markdown]
# ### 3.4 Улучшение решения

# %% [markdown]
# *Предложить возможное улучшение точности решения задачи (выбрать другой тип модели, алгоритм или критерий обучения, сформулировать рекомендации по возможным способам повышения точности модели), обучить модель и сравнить показатели точности с рассчитанными в п.3.2*

# %% [markdown]
# В качестве методов решения задачи бинарной классификации помимо логистической регрессии могут быть использованы методы случайного леса и градиентного бустинга, далее я применю эти методы и сравню результаты.

# %%
# TODO

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# создание и обучение модели градиентного бустинга
gb_clf = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3)
gb_clf.fit(X_train, y_train)

y_pred = gb_clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Точность модели градиентного бустинга: {accuracy:.4f}")

X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.3)

# обучение модели Random Forest
rf_clf = RandomForestClassifier(n_estimators=100)
rf_clf.fit(X_train, y_train)

y_pred_rf = rf_clf.predict(X_test)

# точность модели Random Forest
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f"Точность случайного дерева: {accuracy_rf:.4f}")

logreg = LogisticRegression()
logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)
print('Точность логистистической регрессии: {:.4f}'.format(logreg.score(X_test, y_test)))
# Out:
# Точность модели градиентного бустинга: 0.9591
# Точность случайного дерева: 0.9766
# Точность логистистической регрессии: 0.9883
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Точность модели градиентного бустинга: 0.9591
#
# Точность случайного дерева: 0.9766
#
# Точность логистистической регрессии: 0.9883

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
gb_roc_auc = roc_auc_score(y_test, gb_clf.predict(X_test))
rf_roc_auc = roc_auc_score(y_test, rf_clf.predict(X_test))
fpr, tpr, thresholds1 = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
fpg, tpg, thresholds2 = roc_curve(y_test, gb_clf.predict_proba(X_test)[:,1])
fpf, tpf, thresholds3 = roc_curve(y_test, rf_clf.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Логистическая регрессия (area = %0.2f)' % logit_roc_auc)
plt.plot(fpg, tpg, label='Градиентный бустинг (area = %0.2f)' % gb_roc_auc)
plt.plot(fpf, tpf, label='Случайное дерево (area = %0.2f)' % rf_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC кривая')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %% [markdown]
# ### 3.5 Выводы

# %% [markdown]
# *Сделать выводы по результатам проведенных исследований*

# %% [markdown]
# По результатам проведенных исследований по улучшению моделей можно сделать вывод, что все 3 метода выдают практически идентичный результат, близкий к единице.
#
#
# Все 3 модели обучаются крайне быстро, и выдают отличный результат, что можно увидеть также на roc curve выше. Причиной такого поведения может являться простота датасета, а также сильная дифференциация значений метрик для каждого класса, что позволяет решить задачу бинарной классификации с максимальной точностью.
#
#
# Также можно считать, что такой результат получается ввиду того, что данные являются стандартными в библиотеке scikit-learn.
#
#
# Используя датасет, который был выдан в начале нельзя точно понять какой из методов решения задачи будет являться наиболее точным, так как все показали имеют высокую точность
